# %%
# importing required modules 
from zipfile import ZipFile
import pandas as pd
import os  
# specifying the zip file name 
file_name = "all_data.zip"
  
# # opening the zip file in READ mode 
with ZipFile(file_name, 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
# with ZipFile(file_name, 'r') as zip:
#     zip.printdir()
#     q1_data = zip.read('Q12019.csv')
    
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall('../Untitled Folder/Resources') 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# Q12019.csv                                     2020-06-17 18:58:20    374053926
# Q22019.csv                                     2020-06-17 19:00:04    430250279
# Q32019.csv                                     2020-06-17 19:00:56    411672557
# Q42019.csv                                     2020-06-17 19:01:44    427432025
# Extracting all the files now...
# Done!

# %%
df = pd.read_csv('../Untitled Folder/Q12019.csv')
df
# Out:
#          YEAR  QUARTER ORIGIN ORIGIN_STATE_ABR ORIGIN_STATE_NM DEST  \
# 0        2019        1    CLT               NC  North Carolina  RIC
# 1        2019        1    RIC               VA        Virginia  CLT
# 2        2019        1    CLT               NC  North Carolina  RIC
# 3        2019        1    RIC               VA        Virginia  CLT
# 4        2019        1    CLT               NC  North Carolina  RIC
# ...       ...      ...    ...              ...             ...  ...
# 6508748  2019        1    SAT               TX           Texas  TUL
# 6508749  2019        1    SAT               TX           Texas  TUL
# 6508750  2019        1    SAT               TX           Texas  TUL
# 6508751  2019        1    SAT               TX           Texas  TUL
# 6508752  2019        1    SAT               TX           Texas  TUL
#
#         DEST_STATE_ABR   DEST_STATE_NM  PASSENGERS  Unnamed: 9
# 0                   VA        Virginia         1.0         NaN
# ...

# %%
zipObj = ZipFile('sample.zip', 'w')
zipObj.write('../Untitled Folder/Q12019.csv')
zipObj.write('../Untitled Folder/Q22019.csv')
zipObj.write('../Untitled Folder/Q32019.csv')
zipObj.close()
